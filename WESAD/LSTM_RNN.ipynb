# %%
# Load necessary libraries

# %%
import numpy as np
import os
import keras as ks
from keras.callbacks import Callback
from keras.optimizers import Adam
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras.models import Sequential
from keras.models import load_model
from keras import backend as K
from keras import objectives
import scipy.io as scio
import gzip
from six.moves import cPickle
import sys, random
from sklearn.model_selection import train_test_split

import math
from sklearn import mixture
from sklearn.cluster import KMeans
from keras.models import model_from_json
import json
import glob
import pandas as pd
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
from scipy.ndimage import gaussian_filter
from collections import defaultdict
from scipy.ndimage import label
import warnings
from sklearn.preprocessing import MaxAbsScaler
import itertools
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import accuracy_score, auc, f1_score
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
warnings.filterwarnings("ignore")


font = {'weight' : 'bold',
        'size'   : 18}
import matplotlib
matplotlib.rc('font', **font)

from numpy import array
import keras 
from tensorflow.python.keras.utils.data_utils import Sequence
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import ConvLSTM2D
from keras.layers import Embedding
from keras.layers import Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0',
#  '/job:localhost/replica:0/task:0/device:GPU:1',
#  '/job:localhost/replica:0/task:0/device:GPU:2']

# %% [markdown]
# Select the GPU for running the rest of the model

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = "GPU:1"

# %% [markdown]
# Creating the data generator class

# %%
class data_generator:
''' This class has essential functions supporting
fast and effective computation for reading the raw data, droping the irrelevant lables, 
preparing the input data and generating the batch to be used in LSTM model.'''
    
    def __init__(self, path_to_data = 'None'):
        super().__init__()
        self.path = path_to_data
        self.fileDic = self.readFiles()
        self.users = list(self.fileDic.keys())
        self.train = [key for key in self.users if key not in ['S11', 'S10', 'S4']]
        self.test = { your_key: self.fileDic[your_key] for your_key in ['S11', 'S10', 'S4']}
        self.fileDic = { your_key: self.fileDic[your_key] for your_key in self.train }
        self.users = list(self.fileDic.keys())
        self.keys = ['Resp', 'ECG', 'ACC', 'Temp', 'EDA', 'EMG']
        self.mask_data()
        self.mask_test_data()
        
    def readFiles(self):
        fileDic = {}
        files = [file for file in glob.glob('Data/*.pkl')]
        for name in tqdm(files):
            file = pickle.load(open(name, 'rb'), encoding = 'latin1')
            fileDic[name.split('.')[0].split('/')[-1]] = file
        return fileDic
    
    def mask_data(self):
        ''' This function drops the irrelevant lables of the train set for this project.
        USAGE: Mask the irrelevant features associated with irrelevant labels that are not used in this study 
        OUTPUT: New dictionary without the irrelevant features and labels for the train set'''
        for user in self.users:
            mask = np.isin(self.fileDic[user]['label'], [0,4,5,6,7], invert=True)
            self.fileDic[user]['label'] = self.fileDic[user]['label'][mask]
            self.fileDic[user]['label'] = self.fileDic[user]['label'] - 1
            self.fileDic[user]['label'] = keras.utils.to_categorical(self.fileDic[user]['label'],
                                                                                      num_classes=3, dtype='float32')
            for key in self.keys:
                self.fileDic[user]['signal']['chest'][key] = self.fileDic[user]['signal']['chest'][key][mask]
    
    def mask_test_data(self):
        ''' This function drops the irrelevant lables of the test set for this project.
        USAGE: Mask the irrelevant features associated with irrelevant labels that are not used in this study 
        OUTPUT: New dictionary without the irrelevant features and labels for the test set'''
        for user in self.test:
            mask = np.isin(self.test[user]['label'], [0,4,5,6,7], invert=True)
            self.test[user]['label'] = self.test[user]['label'][mask]
            self.test[user]['label'] = self.test[user]['label'] - 1
            self.test[user]['label'] = keras.utils.to_categorical(self.test[user]['label'], num_classes=3, dtype='float32')
            for key in self.keys:
                self.test[user]['signal']['chest'][key] = self.test[user]['signal']['chest'][key][mask]   
    
    def create_data(self, user, N_samples):
        ''' This function creates and stacks the time series data for the train set.
        USAGE: Create the train dataset
        ARGS: user = string (patient ID), N_samples = Numeric represnting the number of samples for picking the records
        OUTPUT: x and y as features and labels'''
        length = self.fileDic[user]['signal']['chest']['ECG'].shape[0]
        max_interval = length//N_samples
        i = np.random.choice(max_interval - 1, 1, replace=True)[0]
        
        x = [np.hstack(self.fileDic[user]['signal']['chest']['ECG'][i*N_samples:(i+1)*N_samples]), 
            np.hstack(self.fileDic[user]['signal']['chest']['EMG'][i*N_samples:(i+1)*N_samples]),
            np.hstack(self.fileDic[user]['signal']['chest']['Temp'][i*N_samples:(i+1)*N_samples]),
            np.hstack(self.fileDic[user]['signal']['chest']['Resp'][i*N_samples:(i+1)*N_samples]),
            np.hstack(self.fileDic[user]['signal']['chest']['EDA'][i*N_samples:(i+1)*N_samples]),
            np.hstack(self.fileDic[user]['signal']['chest']['ACC'][i*N_samples:(i+1)*N_samples, 0]),
            np.hstack(self.fileDic[user]['signal']['chest']['ACC'][i*N_samples:(i+1)*N_samples, 1]),
            np.hstack(self.fileDic[user]['signal']['chest']['ACC'][i*N_samples:(i+1)*N_samples, 2])]

        y = self.fileDic[user]['label'][i*N_samples:(i+1)*N_samples]
        return x, y[int(N_samples/2) + 2]   
        
    
    def create_test_data(self, user, N_samples = 256):
        ''' This function creates and stacks the time series data for the test set.
        USAGE: Create the test dataset
        ARGS: user = string (patient ID), N_samples = Numeric represnting the number of samples for picking the records
        OUTPUT: X and Y as features and labels'''
        length = self.test[user]['signal']['chest']['ECG'].shape[0]
        max_interval = length//N_samples
        i = np.random.choice(max_interval - 1, 1, replace=True)[0]
        X = []
        Y = []
        for i in range(max_interval):
            X.append([np.hstack(self.test[user]['signal']['chest']['ECG'][i*N_samples:(i+1)*N_samples]), 
                np.hstack(self.test[user]['signal']['chest']['EMG'][i*N_samples:(i+1)*N_samples]),
                np.hstack(self.test[user]['signal']['chest']['Temp'][i*N_samples:(i+1)*N_samples]),
                np.hstack(self.test[user]['signal']['chest']['Resp'][i*N_samples:(i+1)*N_samples]),
                np.hstack(self.test[user]['signal']['chest']['EDA'][i*N_samples:(i+1)*N_samples]),
                np.hstack(self.test[user]['signal']['chest']['ACC'][i*N_samples:(i+1)*N_samples, 0]),
                np.hstack(self.test[user]['signal']['chest']['ACC'][i*N_samples:(i+1)*N_samples, 1]),
                np.hstack(self.test[user]['signal']['chest']['ACC'][i*N_samples:(i+1)*N_samples, 2])])

            Y.append(self.test[user]['label'][i*N_samples:(i+1)*N_samples][int(N_samples/2) + 2])
            
        return X, Y


    def batch_generator_train(self, batch_size = 8, N_samples=256):
        ''' This function generates the batch for the train set.
        USAGE: Generate the train batch 
        ARGS: batch_size = Numeric representing the batch size (number of patients), N_samples = Numeric represnting the number of samples for picking the records
        OUTPUT: Train batch for X and Y'''
        while True:
            # create the indicies
            self.batch_indices_tr = np.random.choice(len(self.users), batch_size, replace=True)  
            users_to_pick = [self.users[i] for i in self.batch_indices_tr]
            
            batch_tr = np.array([self.create_data(user, N_samples) for user in users_to_pick])
            
            batch_tr_X = np.array([batch_tr[i][0] for i in range(len(batch_tr))])
            batch_tr_Y = np.vstack([batch_tr[i][1] for i in range(len(batch_tr))])
            # yield the data
            
            yield (batch_tr_X, batch_tr_Y)
                        
    def batch_generator_validation(self, batch_size = 4, N_samples=256):
        ''' This function generates the batch for the validation set.
        USAGE: Generate the validation batch 
        ARGS: batch_size = Numeric representing the batch size (number of patients), N_samples = Numeric represnting the number of samples for picking the records
        OUTPUT: Validation batch for X and Y'''
        while True:
            # create the indicies
            self.batch_indices_tr = np.random.choice(len(self.users), batch_size, replace=True)  
            users_to_pick = [self.users[i] for i in self.batch_indices_tr]
            
            batch_tr = np.array([self.create_data(user, N_samples) for user in users_to_pick])
            
            batch_tr_X = np.array([batch_tr[i][0] for i in range(len(batch_tr))])
            batch_tr_Y = np.vstack([batch_tr[i][1] for i in range(len(batch_tr))])
            
            # yield the data
            yield (batch_tr_X, batch_tr_Y)
    
    
    def batch_generator_test(self, batch_size = 8, N_samples=256):
        ''' This function generates the batch for the test set.
        USAGE: Generate the test batch 
        ARGS: batch_size = Numeric representing the batch size (number of patients), N_samples = Numeric represnting the number of samples for picking the records
        OUTPUT: Test batch for X and Y'''
        while True:

            batch_test = np.array([self.create_test_data(user, N_samples) for user in data_gen.test.keys()])

#             batch_test_X = np.array([batch_test[i][0] for i in range(len(batch_test))])
#             batch_test_Y = np.vstack([batch_test[i][1] for i in range(len(batch_test))])
            # yield the data

            return batch_test

# %%
data_gen = data_generator()
# Out:
# 100%|██████████| 15/15 [00:31<00:00,  2.00s/it]

# %%
# https://machinelearningmastery.com/how-to-develop-rnn-models-for-human-activity-recognition-time-series-classification/

# %% [markdown]
# ### Find model with Keras - to run LSTM with batch generator

# %%
x, y = next(data_gen.batch_generator_train(batch_size=8, N_samples=256))
n_timesteps, n_features, n_outputs = x.shape[1], x.shape[2], y.shape[1]

# %%
n_timesteps
# Out:
# 8

# %%
model = Sequential()
model.add(LSTM(256, input_shape=(n_timesteps,n_features)))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
#model.add(LSTM(256, activation = 'relu'))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 723,459
# Trainable params: 723,459
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train and find the best model

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=70, verbose = 0, mode = 'min')
checkpoint_callback = ModelCheckpoint('keras_checkpoint_1.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
model.fit_generator(data_gen.batch_generator_train(batch_size=8, N_samples=256), steps_per_epoch = 32, 
                    verbose=1, validation_data=data_gen.batch_generator_validation(batch_size=4, N_samples=256), validation_steps = 64,
                   epochs=200, callbacks=[early_stopping_callback, checkpoint_callback])
# Out:
# Epoch 1/200
# 32/32 [==============================] - 3s 108ms/step - loss: 0.5852 - acc: 0.6979 - val_loss: 0.5339 - val_acc: 0.7331
#
# Epoch 00001: val_loss improved from inf to 0.53390, saving model to keras_checkpoint_1.h5
# Epoch 2/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.5808 - acc: 0.7018 - val_loss: 0.5878 - val_acc: 0.7057
#
# Epoch 00002: val_loss did not improve from 0.53390
# Epoch 3/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.5610 - acc: 0.7031 - val_loss: 0.5775 - val_acc: 0.7370
#
# Epoch 00003: val_loss did not improve from 0.53390
# Epoch 4/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.5636 - acc: 0.6992 - val_loss: 0.5634 - val_acc: 0.7201
#
# Epoch 00004: val_loss did not improve from 0.53390
# Epoch 5/200
# 32/32 [==============================] - 3s 82ms/step - loss: 0.5289 - acc: 0.7435 - val_loss: 0.5369 - val_acc: 0.7240
#
# Epoch 00005: val_loss did not improve from 0.53390
# Epoch 6/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.5687 - acc: 0.7122 - val_loss: 0.5361 - val_acc: 0.7370
#
# Epoch 00006: val_loss did not improve from 0.53390
# Epoch 7/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.5279 - acc: 0.7396 - val_loss: 0.5135 - val_acc: 0.7318
#
# Epoch 00007: val_loss improved from 0.53390 to 0.51348, saving model to keras_checkpoint_1.h5
# Epoch 8/200
# 32/32 [==============================] - 2s 67ms/step - loss: 0.5348 - acc: 0.7253 - val_loss: 0.5239 - val_acc: 0.7174
#
# Epoch 00008: val_loss did not improve from 0.51348
# Epoch 9/200
# 32/32 [==============================] - 3s 78ms/step - loss: 0.5584 - acc: 0.7227 - val_loss: 0.5573 - val_acc: 0.7253
#
# Epoch 00009: val_loss did not improve from 0.51348
# Epoch 10/200
# 32/32 [==============================] - 3s 81ms/step - loss: 0.5571 - acc: 0.7174 - val_loss: 0.4941 - val_acc: 0.7396
#
# Epoch 00010: val_loss improved from 0.51348 to 0.49407, saving model to keras_checkpoint_1.h5
# Epoch 11/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.5347 - acc: 0.7344 - val_loss: 0.5405 - val_acc: 0.7279
#
# Epoch 00011: val_loss did not improve from 0.49407
# Epoch 12/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.5737 - acc: 0.7044 - val_loss: 0.5478 - val_acc: 0.7240
#
# Epoch 00012: val_loss did not improve from 0.49407
# Epoch 13/200
# 32/32 [==============================] - 3s 82ms/step - loss: 0.5294 - acc: 0.7174 - val_loss: 0.5408 - val_acc: 0.7201
#
# Epoch 00013: val_loss did not improve from 0.49407
# Epoch 14/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.5014 - acc: 0.7435 - val_loss: 0.5244 - val_acc: 0.7318
#
# Epoch 00014: val_loss did not improve from 0.49407
# Epoch 15/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.5426 - acc: 0.7240 - val_loss: 0.5426 - val_acc: 0.7253
#
# Epoch 00015: val_loss did not improve from 0.49407
# Epoch 16/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.5587 - acc: 0.7083 - val_loss: 0.5015 - val_acc: 0.7409
#
# Epoch 00016: val_loss did not improve from 0.49407
# Epoch 17/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.5071 - acc: 0.7344 - val_loss: 0.4984 - val_acc: 0.7500
#
# Epoch 00017: val_loss did not improve from 0.49407
# Epoch 18/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4968 - acc: 0.7487 - val_loss: 0.4726 - val_acc: 0.7565
#
# Epoch 00018: val_loss improved from 0.49407 to 0.47260, saving model to keras_checkpoint_1.h5
# Epoch 19/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.5754 - acc: 0.7083 - val_loss: 0.5282 - val_acc: 0.7292
#
# Epoch 00019: val_loss did not improve from 0.47260
# Epoch 20/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4920 - acc: 0.7513 - val_loss: 0.4931 - val_acc: 0.7357
#
# Epoch 00020: val_loss did not improve from 0.47260
# Epoch 21/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.5072 - acc: 0.7422 - val_loss: 0.4917 - val_acc: 0.7500
#
# Epoch 00021: val_loss did not improve from 0.47260
# Epoch 22/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.5147 - acc: 0.7435 - val_loss: 0.5175 - val_acc: 0.7370
#
# Epoch 00022: val_loss did not improve from 0.47260
# Epoch 23/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.5379 - acc: 0.7083 - val_loss: 0.5468 - val_acc: 0.7240
#
# Epoch 00023: val_loss did not improve from 0.47260
# Epoch 24/200
# 32/32 [==============================] - 3s 83ms/step - loss: 0.5261 - acc: 0.7357 - val_loss: 0.5123 - val_acc: 0.7409
#
# Epoch 00024: val_loss did not improve from 0.47260
# Epoch 25/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.5212 - acc: 0.7331 - val_loss: 0.5567 - val_acc: 0.6654
#
# Epoch 00025: val_loss did not improve from 0.47260
# Epoch 26/200
# 32/32 [==============================] - 3s 78ms/step - loss: 0.5047 - acc: 0.7370 - val_loss: 0.4753 - val_acc: 0.7682
#
# Epoch 00026: val_loss did not improve from 0.47260
# Epoch 27/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4991 - acc: 0.7630 - val_loss: 0.5068 - val_acc: 0.7500
#
# Epoch 00027: val_loss did not improve from 0.47260
# Epoch 28/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4993 - acc: 0.7708 - val_loss: 0.5022 - val_acc: 0.7565
#
# Epoch 00028: val_loss did not improve from 0.47260
# Epoch 29/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4908 - acc: 0.7708 - val_loss: 0.4656 - val_acc: 0.7695
#
# Epoch 00029: val_loss improved from 0.47260 to 0.46563, saving model to keras_checkpoint_1.h5
# Epoch 30/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4938 - acc: 0.7643 - val_loss: 0.4669 - val_acc: 0.7617
#
# Epoch 00030: val_loss did not improve from 0.46563
# Epoch 31/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4470 - acc: 0.7813 - val_loss: 0.4624 - val_acc: 0.7604
#
# Epoch 00031: val_loss improved from 0.46563 to 0.46239, saving model to keras_checkpoint_1.h5
# Epoch 32/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4316 - acc: 0.7799 - val_loss: 0.4551 - val_acc: 0.7786
#
# Epoch 00032: val_loss improved from 0.46239 to 0.45512, saving model to keras_checkpoint_1.h5
# Epoch 33/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4055 - acc: 0.8021 - val_loss: 0.4553 - val_acc: 0.7799
#
# Epoch 00033: val_loss did not improve from 0.45512
# Epoch 34/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4807 - acc: 0.7773 - val_loss: 0.4189 - val_acc: 0.8034
#
# Epoch 00034: val_loss improved from 0.45512 to 0.41886, saving model to keras_checkpoint_1.h5
# Epoch 35/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4711 - acc: 0.7682 - val_loss: 0.4568 - val_acc: 0.7630
#
# Epoch 00035: val_loss did not improve from 0.41886
# Epoch 36/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4723 - acc: 0.7799 - val_loss: 0.4401 - val_acc: 0.7760
#
# Epoch 00036: val_loss did not improve from 0.41886
# Epoch 37/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4312 - acc: 0.7956 - val_loss: 0.4625 - val_acc: 0.7669
#
# Epoch 00037: val_loss did not improve from 0.41886
# Epoch 38/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4456 - acc: 0.7747 - val_loss: 0.4601 - val_acc: 0.7734
#
# Epoch 00038: val_loss did not improve from 0.41886
# Epoch 39/200
# 32/32 [==============================] - 3s 83ms/step - loss: 0.5001 - acc: 0.7578 - val_loss: 0.4376 - val_acc: 0.7930
#
# Epoch 00039: val_loss did not improve from 0.41886
# Epoch 40/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4847 - acc: 0.7552 - val_loss: 0.4171 - val_acc: 0.8034
#
# Epoch 00040: val_loss improved from 0.41886 to 0.41709, saving model to keras_checkpoint_1.h5
# Epoch 41/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3995 - acc: 0.8151 - val_loss: 0.4386 - val_acc: 0.7852
#
# Epoch 00041: val_loss did not improve from 0.41709
# Epoch 42/200
# 32/32 [==============================] - 3s 82ms/step - loss: 0.4713 - acc: 0.7773 - val_loss: 0.4726 - val_acc: 0.7695
#
# Epoch 00042: val_loss did not improve from 0.41709
# Epoch 43/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.4624 - acc: 0.7734 - val_loss: 0.5044 - val_acc: 0.7695
#
# Epoch 00043: val_loss did not improve from 0.41709
# Epoch 44/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4670 - acc: 0.7904 - val_loss: 0.4528 - val_acc: 0.7969
#
# Epoch 00044: val_loss did not improve from 0.41709
# Epoch 45/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4519 - acc: 0.7813 - val_loss: 0.4309 - val_acc: 0.7943
#
# Epoch 00045: val_loss did not improve from 0.41709
# Epoch 46/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4249 - acc: 0.7969 - val_loss: 0.4614 - val_acc: 0.7891
#
# Epoch 00046: val_loss did not improve from 0.41709
# Epoch 47/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4688 - acc: 0.7878 - val_loss: 0.4156 - val_acc: 0.8060
#
# Epoch 00047: val_loss improved from 0.41709 to 0.41559, saving model to keras_checkpoint_1.h5
# Epoch 48/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.4060 - acc: 0.8125 - val_loss: 0.4308 - val_acc: 0.7826
#
# Epoch 00048: val_loss did not improve from 0.41559
# Epoch 49/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4758 - acc: 0.7682 - val_loss: 0.4121 - val_acc: 0.7982
#
# Epoch 00049: val_loss improved from 0.41559 to 0.41213, saving model to keras_checkpoint_1.h5
# Epoch 50/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4779 - acc: 0.7682 - val_loss: 0.4770 - val_acc: 0.7552
#
# Epoch 00050: val_loss did not improve from 0.41213
# Epoch 51/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4693 - acc: 0.7617 - val_loss: 0.4200 - val_acc: 0.7930
#
# Epoch 00051: val_loss did not improve from 0.41213
# Epoch 52/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.4452 - acc: 0.7852 - val_loss: 0.4277 - val_acc: 0.7904
#
# Epoch 00052: val_loss did not improve from 0.41213
# Epoch 53/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4230 - acc: 0.7904 - val_loss: 0.4482 - val_acc: 0.7799
#
# Epoch 00053: val_loss did not improve from 0.41213
# Epoch 54/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.4241 - acc: 0.8099 - val_loss: 0.4616 - val_acc: 0.7799
#
# Epoch 00054: val_loss did not improve from 0.41213
# Epoch 55/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4280 - acc: 0.7943 - val_loss: 0.4273 - val_acc: 0.8151
#
# Epoch 00055: val_loss did not improve from 0.41213
# Epoch 56/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4446 - acc: 0.7799 - val_loss: 0.4529 - val_acc: 0.7591
#
# Epoch 00056: val_loss did not improve from 0.41213
# Epoch 57/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4517 - acc: 0.7786 - val_loss: 0.4348 - val_acc: 0.8073
#
# Epoch 00057: val_loss did not improve from 0.41213
# Epoch 58/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.4335 - acc: 0.7852 - val_loss: 0.4601 - val_acc: 0.7826
#
# Epoch 00058: val_loss did not improve from 0.41213
# Epoch 59/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.4353 - acc: 0.7786 - val_loss: 0.3796 - val_acc: 0.8477
#
# Epoch 00059: val_loss improved from 0.41213 to 0.37955, saving model to keras_checkpoint_1.h5
# Epoch 60/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3675 - acc: 0.8385 - val_loss: 0.3311 - val_acc: 0.8568
#
# Epoch 00060: val_loss improved from 0.37955 to 0.33106, saving model to keras_checkpoint_1.h5
# Epoch 61/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4470 - acc: 0.7891 - val_loss: 0.3838 - val_acc: 0.8294
#
# Epoch 00061: val_loss did not improve from 0.33106
# Epoch 62/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4242 - acc: 0.8190 - val_loss: 0.4399 - val_acc: 0.7891
#
# Epoch 00062: val_loss did not improve from 0.33106
# Epoch 63/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4466 - acc: 0.7839 - val_loss: 0.4407 - val_acc: 0.7773
#
# Epoch 00063: val_loss did not improve from 0.33106
# Epoch 64/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.4207 - acc: 0.8034 - val_loss: 0.4252 - val_acc: 0.8047
#
# Epoch 00064: val_loss did not improve from 0.33106
# Epoch 65/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4294 - acc: 0.7956 - val_loss: 0.4218 - val_acc: 0.8073
#
# Epoch 00065: val_loss did not improve from 0.33106
# Epoch 66/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4578 - acc: 0.8034 - val_loss: 0.3588 - val_acc: 0.8516
#
# Epoch 00066: val_loss did not improve from 0.33106
# Epoch 67/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.4090 - acc: 0.8229 - val_loss: 0.4413 - val_acc: 0.7839
#
# Epoch 00067: val_loss did not improve from 0.33106
# Epoch 68/200
# 32/32 [==============================] - 3s 82ms/step - loss: 0.4007 - acc: 0.8242 - val_loss: 0.4008 - val_acc: 0.8320
#
# Epoch 00068: val_loss did not improve from 0.33106
# Epoch 69/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4445 - acc: 0.7852 - val_loss: 0.4129 - val_acc: 0.8021
#
# Epoch 00069: val_loss did not improve from 0.33106
# Epoch 70/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4349 - acc: 0.7917 - val_loss: 0.4054 - val_acc: 0.8138
#
# Epoch 00070: val_loss did not improve from 0.33106
# Epoch 71/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4201 - acc: 0.7956 - val_loss: 0.3840 - val_acc: 0.8112
#
# Epoch 00071: val_loss did not improve from 0.33106
# Epoch 72/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.3746 - acc: 0.8320 - val_loss: 0.3705 - val_acc: 0.8320
#
# Epoch 00072: val_loss did not improve from 0.33106
# Epoch 73/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4715 - acc: 0.7721 - val_loss: 0.4657 - val_acc: 0.7839
#
# Epoch 00073: val_loss did not improve from 0.33106
# Epoch 74/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4339 - acc: 0.7865 - val_loss: 0.4047 - val_acc: 0.8008
#
# Epoch 00074: val_loss did not improve from 0.33106
# Epoch 75/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.3885 - acc: 0.8125 - val_loss: 0.3865 - val_acc: 0.8307
#
# Epoch 00075: val_loss did not improve from 0.33106
# Epoch 76/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4593 - acc: 0.7943 - val_loss: 0.3793 - val_acc: 0.8346
#
# Epoch 00076: val_loss did not improve from 0.33106
# Epoch 77/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4384 - acc: 0.7826 - val_loss: 0.4276 - val_acc: 0.7799
#
# Epoch 00077: val_loss did not improve from 0.33106
# Epoch 78/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4431 - acc: 0.7799 - val_loss: 0.3557 - val_acc: 0.8281
#
# Epoch 00078: val_loss did not improve from 0.33106
# Epoch 79/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4157 - acc: 0.8034 - val_loss: 0.5074 - val_acc: 0.7422
#
# Epoch 00079: val_loss did not improve from 0.33106
# Epoch 80/200
# 32/32 [==============================] - 3s 78ms/step - loss: 0.4633 - acc: 0.7917 - val_loss: 0.4329 - val_acc: 0.8047
#
# Epoch 00080: val_loss did not improve from 0.33106
# Epoch 81/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4475 - acc: 0.7839 - val_loss: 0.3942 - val_acc: 0.8333
#
# Epoch 00081: val_loss did not improve from 0.33106
# Epoch 82/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3767 - acc: 0.8268 - val_loss: 0.3690 - val_acc: 0.8294
#
# Epoch 00082: val_loss did not improve from 0.33106
# Epoch 83/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4104 - acc: 0.7930 - val_loss: 0.3728 - val_acc: 0.8372
#
# Epoch 00083: val_loss did not improve from 0.33106
# Epoch 84/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.3892 - acc: 0.8164 - val_loss: 0.3739 - val_acc: 0.8138
#
# Epoch 00084: val_loss did not improve from 0.33106
# Epoch 85/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4064 - acc: 0.8307 - val_loss: 0.3367 - val_acc: 0.8438
#
# Epoch 00085: val_loss did not improve from 0.33106
# Epoch 86/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.4041 - acc: 0.8151 - val_loss: 0.3298 - val_acc: 0.8633
#
# Epoch 00086: val_loss improved from 0.33106 to 0.32981, saving model to keras_checkpoint_1.h5
# Epoch 87/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3545 - acc: 0.8516 - val_loss: 0.3539 - val_acc: 0.8451
#
# Epoch 00087: val_loss did not improve from 0.32981
# Epoch 88/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3807 - acc: 0.8164 - val_loss: 0.3553 - val_acc: 0.8216
#
# Epoch 00088: val_loss did not improve from 0.32981
# Epoch 89/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3519 - acc: 0.8359 - val_loss: 0.4707 - val_acc: 0.7878
#
# Epoch 00089: val_loss did not improve from 0.32981
# Epoch 90/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4297 - acc: 0.7995 - val_loss: 0.4096 - val_acc: 0.8190
#
# Epoch 00090: val_loss did not improve from 0.32981
# Epoch 91/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4387 - acc: 0.7852 - val_loss: 0.4438 - val_acc: 0.7721
#
# Epoch 00091: val_loss did not improve from 0.32981
# Epoch 92/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3768 - acc: 0.8125 - val_loss: 0.3810 - val_acc: 0.8177
#
# Epoch 00092: val_loss did not improve from 0.32981
# Epoch 93/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3422 - acc: 0.8438 - val_loss: 0.3345 - val_acc: 0.8411
#
# Epoch 00093: val_loss did not improve from 0.32981
# Epoch 94/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.3962 - acc: 0.8268 - val_loss: 0.3623 - val_acc: 0.8451
#
# Epoch 00094: val_loss did not improve from 0.32981
# Epoch 95/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.3614 - acc: 0.8294 - val_loss: 0.3741 - val_acc: 0.8294
#
# Epoch 00095: val_loss did not improve from 0.32981
# Epoch 96/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.3782 - acc: 0.8307 - val_loss: 0.3934 - val_acc: 0.8333
#
# Epoch 00096: val_loss did not improve from 0.32981
# Epoch 97/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3774 - acc: 0.8294 - val_loss: 0.3495 - val_acc: 0.8255
#
# Epoch 00097: val_loss did not improve from 0.32981
# Epoch 98/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.3775 - acc: 0.8177 - val_loss: 0.4237 - val_acc: 0.8034
#
# Epoch 00098: val_loss did not improve from 0.32981
# Epoch 99/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.4227 - acc: 0.8073 - val_loss: 0.4174 - val_acc: 0.7943
#
# Epoch 00099: val_loss did not improve from 0.32981
# Epoch 100/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3698 - acc: 0.8138 - val_loss: 0.3566 - val_acc: 0.8255
#
# Epoch 00100: val_loss did not improve from 0.32981
# Epoch 101/200
# 32/32 [==============================] - 2s 70ms/step - loss: 0.4630 - acc: 0.7904 - val_loss: 0.3635 - val_acc: 0.8385
#
# Epoch 00101: val_loss did not improve from 0.32981
# Epoch 102/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3534 - acc: 0.8503 - val_loss: 0.3120 - val_acc: 0.8685
#
# Epoch 00102: val_loss improved from 0.32981 to 0.31199, saving model to keras_checkpoint_1.h5
# Epoch 103/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4201 - acc: 0.8073 - val_loss: 0.3485 - val_acc: 0.8542
#
# Epoch 00103: val_loss did not improve from 0.31199
# Epoch 104/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3455 - acc: 0.8372 - val_loss: 0.3322 - val_acc: 0.8398
#
# Epoch 00104: val_loss did not improve from 0.31199
# Epoch 105/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3947 - acc: 0.8151 - val_loss: 0.4135 - val_acc: 0.7995
#
# Epoch 00105: val_loss did not improve from 0.31199
# Epoch 106/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4092 - acc: 0.8034 - val_loss: 0.3485 - val_acc: 0.8164
#
# Epoch 00106: val_loss did not improve from 0.31199
# Epoch 107/200
# 32/32 [==============================] - 3s 82ms/step - loss: 0.4149 - acc: 0.8190 - val_loss: 0.3621 - val_acc: 0.8372
#
# Epoch 00107: val_loss did not improve from 0.31199
# Epoch 108/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3726 - acc: 0.8242 - val_loss: 0.3666 - val_acc: 0.8346
#
# Epoch 00108: val_loss did not improve from 0.31199
# Epoch 109/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.4085 - acc: 0.8164 - val_loss: 0.3797 - val_acc: 0.8359
#
# Epoch 00109: val_loss did not improve from 0.31199
# Epoch 110/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3674 - acc: 0.8411 - val_loss: 0.2823 - val_acc: 0.8750
#
# Epoch 00110: val_loss improved from 0.31199 to 0.28232, saving model to keras_checkpoint_1.h5
# Epoch 111/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.4645 - acc: 0.7930 - val_loss: 0.3691 - val_acc: 0.8346
#
# Epoch 00111: val_loss did not improve from 0.28232
# Epoch 112/200
# 32/32 [==============================] - 3s 86ms/step - loss: 0.3919 - acc: 0.8216 - val_loss: 0.3768 - val_acc: 0.8307
#
# Epoch 00112: val_loss did not improve from 0.28232
# Epoch 113/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3737 - acc: 0.8359 - val_loss: 0.3611 - val_acc: 0.8464
#
# Epoch 00113: val_loss did not improve from 0.28232
# Epoch 114/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4279 - acc: 0.7943 - val_loss: 0.3740 - val_acc: 0.8320
#
# Epoch 00114: val_loss did not improve from 0.28232
# Epoch 115/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3790 - acc: 0.8333 - val_loss: 0.3686 - val_acc: 0.8229
#
# Epoch 00115: val_loss did not improve from 0.28232
# Epoch 116/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4025 - acc: 0.8125 - val_loss: 0.3110 - val_acc: 0.8698
#
# Epoch 00116: val_loss did not improve from 0.28232
# Epoch 117/200
# 32/32 [==============================] - 3s 78ms/step - loss: 0.3195 - acc: 0.8503 - val_loss: 0.3336 - val_acc: 0.8411
#
# Epoch 00117: val_loss did not improve from 0.28232
# Epoch 118/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.3454 - acc: 0.8529 - val_loss: 0.3560 - val_acc: 0.8229
#
# Epoch 00118: val_loss did not improve from 0.28232
# Epoch 119/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3811 - acc: 0.8307 - val_loss: 0.3203 - val_acc: 0.8555
#
# Epoch 00119: val_loss did not improve from 0.28232
# Epoch 120/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3713 - acc: 0.8268 - val_loss: 0.3845 - val_acc: 0.8333
#
# Epoch 00120: val_loss did not improve from 0.28232
# Epoch 121/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.3857 - acc: 0.8203 - val_loss: 0.3452 - val_acc: 0.8385
#
# Epoch 00121: val_loss did not improve from 0.28232
# Epoch 122/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3256 - acc: 0.8633 - val_loss: 0.3891 - val_acc: 0.8190
#
# Epoch 00122: val_loss did not improve from 0.28232
# Epoch 123/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3702 - acc: 0.8438 - val_loss: 0.3917 - val_acc: 0.8190
#
# Epoch 00123: val_loss did not improve from 0.28232
# Epoch 124/200
# 32/32 [==============================] - 3s 81ms/step - loss: 0.3888 - acc: 0.8242 - val_loss: 0.3445 - val_acc: 0.8542
#
# Epoch 00124: val_loss did not improve from 0.28232
# Epoch 125/200
# 32/32 [==============================] - 2s 69ms/step - loss: 0.3349 - acc: 0.8529 - val_loss: 0.3479 - val_acc: 0.8424
#
# Epoch 00125: val_loss did not improve from 0.28232
# Epoch 126/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3709 - acc: 0.8151 - val_loss: 0.3188 - val_acc: 0.8542
#
# Epoch 00126: val_loss did not improve from 0.28232
# Epoch 127/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4066 - acc: 0.8268 - val_loss: 0.3654 - val_acc: 0.8333
#
# Epoch 00127: val_loss did not improve from 0.28232
# Epoch 128/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4094 - acc: 0.8138 - val_loss: 0.3463 - val_acc: 0.8503
#
# Epoch 00128: val_loss did not improve from 0.28232
# Epoch 129/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3462 - acc: 0.8398 - val_loss: 0.3009 - val_acc: 0.8581
#
# Epoch 00129: val_loss did not improve from 0.28232
# Epoch 130/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3030 - acc: 0.8620 - val_loss: 0.3555 - val_acc: 0.8464
#
# Epoch 00130: val_loss did not improve from 0.28232
# Epoch 131/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.3351 - acc: 0.8555 - val_loss: 0.3280 - val_acc: 0.8438
#
# Epoch 00131: val_loss did not improve from 0.28232
# Epoch 132/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3740 - acc: 0.8359 - val_loss: 0.3197 - val_acc: 0.8581
#
# Epoch 00132: val_loss did not improve from 0.28232
# Epoch 133/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4078 - acc: 0.8047 - val_loss: 0.3776 - val_acc: 0.8112
#
# Epoch 00133: val_loss did not improve from 0.28232
# Epoch 134/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3524 - acc: 0.8438 - val_loss: 0.3561 - val_acc: 0.8281
#
# Epoch 00134: val_loss did not improve from 0.28232
# Epoch 135/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.3829 - acc: 0.8294 - val_loss: 0.2840 - val_acc: 0.8646
#
# Epoch 00135: val_loss did not improve from 0.28232
# Epoch 136/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3328 - acc: 0.8464 - val_loss: 0.3274 - val_acc: 0.8490
#
# Epoch 00136: val_loss did not improve from 0.28232
# Epoch 137/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.3504 - acc: 0.8359 - val_loss: 0.3181 - val_acc: 0.8646
#
# Epoch 00137: val_loss did not improve from 0.28232
# Epoch 138/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.3442 - acc: 0.8477 - val_loss: 0.3478 - val_acc: 0.8268
#
# Epoch 00138: val_loss did not improve from 0.28232
# Epoch 139/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3817 - acc: 0.8151 - val_loss: 0.4090 - val_acc: 0.7904
#
# Epoch 00139: val_loss did not improve from 0.28232
# Epoch 140/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3903 - acc: 0.8151 - val_loss: 0.4061 - val_acc: 0.8307
#
# Epoch 00140: val_loss did not improve from 0.28232
# Epoch 141/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.3799 - acc: 0.8451 - val_loss: 0.3292 - val_acc: 0.8398
#
# Epoch 00141: val_loss did not improve from 0.28232
# Epoch 142/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3853 - acc: 0.8203 - val_loss: 0.3944 - val_acc: 0.8060
#
# Epoch 00142: val_loss did not improve from 0.28232
# Epoch 143/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4033 - acc: 0.8112 - val_loss: 0.3134 - val_acc: 0.8594
#
# Epoch 00143: val_loss did not improve from 0.28232
# Epoch 144/200
# 32/32 [==============================] - 2s 66ms/step - loss: 0.3660 - acc: 0.8255 - val_loss: 0.3470 - val_acc: 0.8464
#
# Epoch 00144: val_loss did not improve from 0.28232
# Epoch 145/200
# 32/32 [==============================] - 3s 82ms/step - loss: 0.3838 - acc: 0.8268 - val_loss: 0.3937 - val_acc: 0.8229
#
# Epoch 00145: val_loss did not improve from 0.28232
# Epoch 146/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3632 - acc: 0.8346 - val_loss: 0.3119 - val_acc: 0.8633
#
# Epoch 00146: val_loss did not improve from 0.28232
# Epoch 147/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3427 - acc: 0.8411 - val_loss: 0.3362 - val_acc: 0.8346
#
# Epoch 00147: val_loss did not improve from 0.28232
# Epoch 148/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3918 - acc: 0.8385 - val_loss: 0.3303 - val_acc: 0.8464
#
# Epoch 00148: val_loss did not improve from 0.28232
# Epoch 149/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3618 - acc: 0.8268 - val_loss: 0.3183 - val_acc: 0.8503
#
# Epoch 00149: val_loss did not improve from 0.28232
# Epoch 150/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3716 - acc: 0.8424 - val_loss: 0.3601 - val_acc: 0.8333
#
# Epoch 00150: val_loss did not improve from 0.28232
# Epoch 151/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3625 - acc: 0.8398 - val_loss: 0.3354 - val_acc: 0.8320
#
# Epoch 00151: val_loss did not improve from 0.28232
# Epoch 152/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.3500 - acc: 0.8385 - val_loss: 0.3215 - val_acc: 0.8529
#
# Epoch 00152: val_loss did not improve from 0.28232
# Epoch 153/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3413 - acc: 0.8294 - val_loss: 0.3125 - val_acc: 0.8424
#
# Epoch 00153: val_loss did not improve from 0.28232
# Epoch 154/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3112 - acc: 0.8763 - val_loss: 0.3000 - val_acc: 0.8607
#
# Epoch 00154: val_loss did not improve from 0.28232
# Epoch 155/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3730 - acc: 0.8346 - val_loss: 0.3197 - val_acc: 0.8620
#
# Epoch 00155: val_loss did not improve from 0.28232
# Epoch 156/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.3157 - acc: 0.8555 - val_loss: 0.3200 - val_acc: 0.8581
#
# Epoch 00156: val_loss did not improve from 0.28232
# Epoch 157/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3093 - acc: 0.8542 - val_loss: 0.3195 - val_acc: 0.8672
#
# Epoch 00157: val_loss did not improve from 0.28232
# Epoch 158/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3944 - acc: 0.8424 - val_loss: 0.3814 - val_acc: 0.8190
#
# Epoch 00158: val_loss did not improve from 0.28232
# Epoch 159/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3302 - acc: 0.8568 - val_loss: 0.3401 - val_acc: 0.8503
#
# Epoch 00159: val_loss did not improve from 0.28232
# Epoch 160/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3779 - acc: 0.8411 - val_loss: 0.2970 - val_acc: 0.8581
#
# Epoch 00160: val_loss did not improve from 0.28232
# Epoch 161/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3488 - acc: 0.8516 - val_loss: 0.2799 - val_acc: 0.8828
#
# Epoch 00161: val_loss improved from 0.28232 to 0.27995, saving model to keras_checkpoint_1.h5
# Epoch 162/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.3690 - acc: 0.8464 - val_loss: 0.3683 - val_acc: 0.8281
#
# Epoch 00162: val_loss did not improve from 0.27995
# Epoch 163/200
# 32/32 [==============================] - 3s 81ms/step - loss: 0.3434 - acc: 0.8581 - val_loss: 0.3287 - val_acc: 0.8424
#
# Epoch 00163: val_loss did not improve from 0.27995
# Epoch 164/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3517 - acc: 0.8268 - val_loss: 0.3006 - val_acc: 0.8724
#
# Epoch 00164: val_loss did not improve from 0.27995
# Epoch 165/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.3487 - acc: 0.8451 - val_loss: 0.3197 - val_acc: 0.8633
#
# Epoch 00165: val_loss did not improve from 0.27995
# Epoch 166/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.3886 - acc: 0.8060 - val_loss: 0.3623 - val_acc: 0.8333
#
# Epoch 00166: val_loss did not improve from 0.27995
# Epoch 167/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.3213 - acc: 0.8698 - val_loss: 0.3772 - val_acc: 0.8190
#
# Epoch 00167: val_loss did not improve from 0.27995
# Epoch 168/200
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4091 - acc: 0.8112 - val_loss: 0.3461 - val_acc: 0.8568
#
# Epoch 00168: val_loss did not improve from 0.27995
# Epoch 169/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3558 - acc: 0.8216 - val_loss: 0.3014 - val_acc: 0.8464
#
# Epoch 00169: val_loss did not improve from 0.27995
# Epoch 170/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3054 - acc: 0.8568 - val_loss: 0.3528 - val_acc: 0.8307
#
# Epoch 00170: val_loss did not improve from 0.27995
# Epoch 171/200
# 32/32 [==============================] - 3s 78ms/step - loss: 0.3086 - acc: 0.8607 - val_loss: 0.3215 - val_acc: 0.8411
#
# Epoch 00171: val_loss did not improve from 0.27995
# Epoch 172/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.3075 - acc: 0.8607 - val_loss: 0.2908 - val_acc: 0.8737
#
# Epoch 00172: val_loss did not improve from 0.27995
# Epoch 173/200
# 32/32 [==============================] - 2s 68ms/step - loss: 0.3190 - acc: 0.8594 - val_loss: 0.3568 - val_acc: 0.8646
#
# Epoch 00173: val_loss did not improve from 0.27995
# Epoch 174/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3167 - acc: 0.8581 - val_loss: 0.3381 - val_acc: 0.8438
#
# Epoch 00174: val_loss did not improve from 0.27995
# Epoch 175/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3323 - acc: 0.8307 - val_loss: 0.3263 - val_acc: 0.8581
#
# Epoch 00175: val_loss did not improve from 0.27995
# Epoch 176/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.3352 - acc: 0.8659 - val_loss: 0.3729 - val_acc: 0.8359
#
# Epoch 00176: val_loss did not improve from 0.27995
# Epoch 177/200
# 32/32 [==============================] - 3s 83ms/step - loss: 0.3600 - acc: 0.8529 - val_loss: 0.2782 - val_acc: 0.8958
#
# Epoch 00177: val_loss improved from 0.27995 to 0.27817, saving model to keras_checkpoint_1.h5
# Epoch 178/200
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3645 - acc: 0.8255 - val_loss: 0.2567 - val_acc: 0.9036
#
# Epoch 00178: val_loss improved from 0.27817 to 0.25674, saving model to keras_checkpoint_1.h5
# Epoch 179/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.3114 - acc: 0.8464 - val_loss: 0.2560 - val_acc: 0.9023
#
# Epoch 00179: val_loss improved from 0.25674 to 0.25605, saving model to keras_checkpoint_1.h5
# Epoch 180/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.2874 - acc: 0.8724 - val_loss: 0.2943 - val_acc: 0.8698
#
# Epoch 00180: val_loss did not improve from 0.25605
# Epoch 181/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.3229 - acc: 0.8490 - val_loss: 0.3909 - val_acc: 0.8008
#
# Epoch 00181: val_loss did not improve from 0.25605
# Epoch 182/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.4002 - acc: 0.8255 - val_loss: 0.2830 - val_acc: 0.8802
#
# Epoch 00182: val_loss did not improve from 0.25605
# Epoch 183/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3146 - acc: 0.8659 - val_loss: 0.2937 - val_acc: 0.8581
#
# Epoch 00183: val_loss did not improve from 0.25605
# Epoch 184/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3382 - acc: 0.8438 - val_loss: 0.2775 - val_acc: 0.8828
#
# Epoch 00184: val_loss did not improve from 0.25605
# Epoch 185/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.3171 - acc: 0.8529 - val_loss: 0.2892 - val_acc: 0.8568
#
# Epoch 00185: val_loss did not improve from 0.25605
# Epoch 186/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.2913 - acc: 0.8763 - val_loss: 0.3245 - val_acc: 0.8711
#
# Epoch 00186: val_loss did not improve from 0.25605
# Epoch 187/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3811 - acc: 0.8451 - val_loss: 0.2755 - val_acc: 0.8932
#
# Epoch 00187: val_loss did not improve from 0.25605
# Epoch 188/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.2762 - acc: 0.8776 - val_loss: 0.2773 - val_acc: 0.8776
#
# Epoch 00188: val_loss did not improve from 0.25605
# Epoch 189/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3330 - acc: 0.8711 - val_loss: 0.3340 - val_acc: 0.8750
#
# Epoch 00189: val_loss did not improve from 0.25605
# Epoch 190/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.3179 - acc: 0.8555 - val_loss: 0.3069 - val_acc: 0.8529
#
# Epoch 00190: val_loss did not improve from 0.25605
# Epoch 191/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3630 - acc: 0.8268 - val_loss: 0.3212 - val_acc: 0.8542
#
# Epoch 00191: val_loss did not improve from 0.25605
# Epoch 192/200
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3261 - acc: 0.8477 - val_loss: 0.3063 - val_acc: 0.8594
#
# Epoch 00192: val_loss did not improve from 0.25605
# Epoch 193/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3121 - acc: 0.8555 - val_loss: 0.3195 - val_acc: 0.8503
#
# Epoch 00193: val_loss did not improve from 0.25605
# Epoch 194/200
# 32/32 [==============================] - 2s 78ms/step - loss: 0.3612 - acc: 0.8216 - val_loss: 0.2619 - val_acc: 0.8880
#
# Epoch 00194: val_loss did not improve from 0.25605
# Epoch 195/200
# 32/32 [==============================] - 2s 71ms/step - loss: 0.2719 - acc: 0.8815 - val_loss: 0.2067 - val_acc: 0.9258
#
# Epoch 00195: val_loss improved from 0.25605 to 0.20673, saving model to keras_checkpoint_1.h5
# Epoch 196/200
# 32/32 [==============================] - 2s 73ms/step - loss: 0.2672 - acc: 0.8659 - val_loss: 0.2857 - val_acc: 0.8802
#
# Epoch 00196: val_loss did not improve from 0.20673
# Epoch 197/200
# 32/32 [==============================] - 2s 77ms/step - loss: 0.3756 - acc: 0.8294 - val_loss: 0.3295 - val_acc: 0.8568
#
# Epoch 00197: val_loss did not improve from 0.20673
# Epoch 198/200
# 32/32 [==============================] - 2s 72ms/step - loss: 0.3017 - acc: 0.8646 - val_loss: 0.2745 - val_acc: 0.8815
#
# Epoch 00198: val_loss did not improve from 0.20673
# Epoch 199/200
# 32/32 [==============================] - 2s 74ms/step - loss: 0.2998 - acc: 0.8854 - val_loss: 0.3245 - val_acc: 0.8542
#
# Epoch 00199: val_loss did not improve from 0.20673
# Epoch 200/200
# 32/32 [==============================] - 3s 79ms/step - loss: 0.2647 - acc: 0.8867 - val_loss: 0.2988 - val_acc: 0.8659
#
# Epoch 00200: val_loss did not improve from 0.20673

# %%
model.load_weights('keras_checkpoint.h5')

# %%
data_gen.test.keys()
# Out:
# dict_keys(['S11', 'S10', 'S4'])

# %%
x_test = data_gen.batch_generator_test(batch_size=8, N_samples=256)

# %%
test_X = [x[0] for x in x_test]
test_Y = [x[1] for x in x_test]
test_Y = np.vstack(test_Y)
test_X = np.vstack(test_X)

# %%
prediction = model.predict(test_X)
errors = abs(prediction - test_Y)
mape = 100 * np.mean(errors / test_Y)
accuracy = 100 - mape

# %%
errors
# Out:
# array([[0.07798702, 0.07036364, 0.0076233 ],
#        [0.04094309, 0.03955093, 0.00139223],
#        [0.11538738, 0.09370087, 0.02168656],
#        ...,
#        [0.09596918, 0.28173316, 0.18576396],
#        [0.18640466, 0.28467286, 0.09826812],
#        [0.08424709, 0.16128683, 0.07703976]], dtype=float32)

# %%
print('LSTM Model Performance: ')
print('Accuracy = {:0.2f}.'.format(accuracy_score(test_Y.argmax(axis=1), prediction.argmax(axis=1))))
print(classification_report(test_Y.argmax(axis=1), prediction.argmax(axis=1), target_names = ['Neutral', 'Amused', 'Stress']))
# Out:
# LSTM Model Performance:
# Accuracy = 0.80.
#               precision    recall  f1-score   support
#
#      Neutral       0.76      0.97      0.85      9620
#       Amused       0.93      0.63      0.75      5576
#       Stress       0.80      0.59      0.68      3041
#
#    micro avg       0.80      0.80      0.80     18237
#    macro avg       0.83      0.73      0.76     18237
# weighted avg       0.82      0.80      0.79     18237

# %%
print(confusion_matrix(test_Y.argmax(axis=1), prediction.argmax(axis=1)))
# Out:
# [[9313  197  110]
#  [1726 3511  339]
#  [1186   48 1807]]
